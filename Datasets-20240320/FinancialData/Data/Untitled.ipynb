# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
import os 
import glob

# %%
path = os.getcwd() 
csv_files = glob.glob(os.path.join(path, "*.csv")) 
combined_df = {}

# %%
for csv_file in csv_files:
    df = pd.read_csv(    csv_file)
    combined_df[csv_file] = df

# %%
combined_df
# Out:
# {'C:\\Users\\ruiha\\Downloads\\Datasets-20240320\\FinancialData\\Data\\AAPL.csv':             date      open      high       low     close    volume  \
#  0     2014-02-21   69.9727   70.2061   68.8967   68.9821  69757247
#  1     2014-02-24   68.7063   69.5954   68.6104   69.2841  72364950
#  2     2014-02-25   69.5245   69.5488   68.4239   68.5631  58247350
#  3     2014-02-26   68.7667   68.9492   67.7147   67.9446  69131286
#  4     2014-02-27   67.9170   69.4457   67.7738   69.2999  75557321
#  ...          ...       ...       ...       ...       ...       ...
#  1253  2019-02-13  171.3900  172.4800  169.9200  170.1800  22490233
#  1254  2019-02-14  169.7100  171.2615  169.3800  170.8000  21835747
#  1255  2019-02-15  171.2500  171.7000  169.7500  170.4200  24626814
#  1256  2019-02-19  169.7100  171.4400  169.4900  170.9300  18972826
#  1257  2019-02-20  171.1900  173.3200  170.9900  172.0300  26114362
#
# ...
